# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from imblearn.over_sampling import SMOTE

import numpy as np 
import pandas as pd 
import sklearn 
import scipy
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.metrics import classification_report, accuracy_score 
from sklearn.ensemble import IsolationForest 
from sklearn.neighbors import LocalOutlierFactor
from sklearn.svm import OneClassSVM
from pylab import rcParams

rcParams['figure.figsize'] = 14, 8
RANDOM_SEED = 42
# Define labels for the target variable
LABELS = ["Show", "No Show"]

# %%
# Load datasets
no_show = pd.read_csv('no_show.csv')
clinics = pd.read_csv('clinics.csv')
planning_neighborhoods = pd.read_csv('planning_neighborhoods.csv')
no_show_historical = pd.read_csv('no_show_historical.csv')

# %%
planning_neighborhoods.drop(columns=['the_geom'], inplace=True)
no_show.drop(['Appointment ID'],axis='columns',inplace=True)
clinics.drop(['name','type','addr1','addr2'],axis='columns',inplace=True)

# Merging datasets
data = pd.merge(no_show, clinics, left_on='Clinic Location', right_on='clinic', how='left')
data = pd.merge(data, planning_neighborhoods, left_on='Neighborhood', right_on='neighborho', how='left')
data = pd.merge(data, no_show_historical, on='Patient ID', how='left')


data.drop(['Patient ID'],axis='columns',inplace=True)

print('data ',data.columns)
# Out:
# data  Index(['no_show_x', 'Gender', 'Age', 'Alcohol Consumption', 'Hypertension',
#        'Diabetes', 'Appointment Date', 'Schedule Date', 'Appointment Reason',
#        'Clinic Location', 'Specialty', 'Neighborhood', 'clinic', 'lat', 'long',
#        'neighborho', 'no_show_y'],
#       dtype='object')

# %%
data.head()
# Out:
#    no_show_x Gender  Age Alcohol Consumption  Hypertension  Diabetes  \
# 0      False      F   43              5/week         False     False
# 1      False      F   43              5/week         False     False
# 2      False      F   43              5/week         False     False
# 3      False      F   37              0/week         False      True
# 4      False      F   37              0/week         False      True
#
#       Appointment Date        Schedule Date           Appointment Reason  \
# 0  2021-01-14T10:30:00  2020-10-26T00:00:00  CHIROPRACT MANJ 3-4 REGIONS
# 1  2021-01-14T10:30:00  2020-10-26T00:00:00  CHIROPRACT MANJ 3-4 REGIONS
# 2  2021-01-14T10:30:00  2020-10-26T00:00:00  CHIROPRACT MANJ 3-4 REGIONS
# 3  2021-02-17T14:00:00  2021-01-25T00:00:00  OFFICE/OUTPATIENT VISIT EST
# 4  2021-02-17T14:00:00  2021-01-25T00:00:00  OFFICE/OUTPATIENT VISIT EST
#
#   Clinic Location                                Specialty  Neighborhood  \
# 0     Mission Bay                 Human Performance Center  Russian Hill
# 1     Mission Bay                 Human Performance Center  Russian Hill
# 2     Mission Bay                 Human Performance Center  Russian Hill
# 3     Mission Bay  Endocrine, Diabetes & Pregnancy Program    Ocean View
# 4     Mission Bay  Endocrine, Diabetes & Pregnancy Program    Ocean View
#
#         clinic        lat        long    neighborho  no_show_y
# 0  Mission Bay  37.764124 -122.456572  Russian Hill        NaN
# 1  Mission Bay  37.784882 -122.438723  Russian Hill        NaN
# 2  Mission Bay  37.766561 -122.389948  Russian Hill        NaN
# 3  Mission Bay  37.764124 -122.456572    Ocean View        NaN
# 4  Mission Bay  37.784882 -122.438723    Ocean View        NaN

# %%
# Assuming `data` is your DataFrame and 'column_name' is the column you're interested in
unique_values_count = data['Appointment Reason'].nunique()

print(f"The number of unique values in 'column_name' is: {unique_values_count}")
# Out:
# The number of unique values in 'column_name' is: 3872

# %%
data.drop(['Appointment Reason'],axis='columns',inplace=True)

# %%
# Combine no_show_x and no_show_y into a single column
if 'no_show_x' in data.columns and 'no_show_y' in data.columns:
    data['target_no_show'] = data['no_show_x'].fillna(data['no_show_y'])
    print('target column updated')
    # Drop the no_show_x and no_show_y columns
    data.drop(columns=['no_show_x', 'no_show_y'], inplace=True)
else:
    raise KeyError("One or both of 'no_show_x' and 'no_show_y' columns not found in the data.")
# Out:
# target column updated

# %%
data.head()
# Out:
#   Gender  Age Alcohol Consumption  Hypertension  Diabetes  \
# 0      F   43              5/week         False     False
# 1      F   43              5/week         False     False
# 2      F   43              5/week         False     False
# 3      F   37              0/week         False      True
# 4      F   37              0/week         False      True
#
#       Appointment Date        Schedule Date Clinic Location  \
# 0  2021-01-14T10:30:00  2020-10-26T00:00:00     Mission Bay
# 1  2021-01-14T10:30:00  2020-10-26T00:00:00     Mission Bay
# 2  2021-01-14T10:30:00  2020-10-26T00:00:00     Mission Bay
# 3  2021-02-17T14:00:00  2021-01-25T00:00:00     Mission Bay
# 4  2021-02-17T14:00:00  2021-01-25T00:00:00     Mission Bay
#
#                                  Specialty  Neighborhood       clinic  \
# 0                 Human Performance Center  Russian Hill  Mission Bay
# 1                 Human Performance Center  Russian Hill  Mission Bay
# 2                 Human Performance Center  Russian Hill  Mission Bay
# 3  Endocrine, Diabetes & Pregnancy Program    Ocean View  Mission Bay
# 4  Endocrine, Diabetes & Pregnancy Program    Ocean View  Mission Bay
#
#          lat        long    neighborho  target_no_show
# 0  37.764124 -122.456572  Russian Hill           False
# 1  37.784882 -122.438723  Russian Hill           False
# 2  37.766561 -122.389948  Russian Hill           False
# 3  37.764124 -122.456572    Ocean View           False
# 4  37.784882 -122.438723    Ocean View           False

# %%
# Preprocessing
data['Gender'] = data['Gender'].map({'M': 0, 'F': 1})

# %%
# Create age group categories and convert to one-hot encoding
data['age_group'] = pd.cut(data['Age'], bins=[0, 30, 40, 50, 60, 100], labels=['<30', '30-40', '40-50', '50-60', '>60'])
data = pd.get_dummies(data, columns=['age_group'], drop_first=True)

# %%
data.drop(['Age'],axis='columns',inplace=True)

# %%
# Map 'Alcohol Consumption' to numeric values
mapping_dict = {'0/week': 0, '1/week': 1, '5/week': 2, '10/week': 3, '> 14/week': 4}
data['Alcohol Consumption'] = data['Alcohol Consumption'].map(mapping_dict)

# %%
# Convert 'Hypertension' and 'Diabetes' to integer
data['Hypertension'] = data['Hypertension'].astype(int)
data['Diabetes'] = data['Diabetes'].astype(int)

# %%
# Convert 'target_no_show' to integer
data['target_no_show'] = data['target_no_show'].astype(int)

# %%
# Convert date columns to datetime format and extract features
data['Appointment Date'] = pd.to_datetime(data['Appointment Date'])
data['Schedule Date'] = pd.to_datetime(data['Schedule Date'])
data['appointment_day'] = data['Appointment Date'].dt.day
data['appointment_month'] = data['Appointment Date'].dt.month
data['appointment_year'] = data['Appointment Date'].dt.year
data['appointment_dayofweek'] = data['Appointment Date'].dt.dayofweek
data['schedule_day'] = data['Schedule Date'].dt.day
data['schedule_month'] = data['Schedule Date'].dt.month
data['schedule_year'] = data['Schedule Date'].dt.year
data['schedule_dayofweek'] = data['Schedule Date'].dt.dayofweek
data['days_until_appointment'] = (data['Appointment Date'] - data['Schedule Date']).dt.days

# Drop the original date columns if they are not needed anymore
data.drop(columns=['Appointment Date', 'Schedule Date'], inplace=True)

# %%
# Encode categorical variables using one-hot encoding
categorical_columns = ['Clinic Location', 'neighborho']
data = pd.get_dummies(data, columns=categorical_columns, drop_first=True)

# %%
# One-hot encode the 'Appointment Reason', 'Specialty', and 'clinic' columns
data = pd.get_dummies(data, columns=['Specialty', 'clinic'], drop_first=True)

# Drop the 'Neighborhood' column since it's already encoded as neighborho_* columns
data.drop(columns=['Neighborhood'], inplace=True)

# Display the first few rows to verify the changes
data.head()
# Out:
#    Gender  Alcohol Consumption  Hypertension  Diabetes        lat        long  \
# 0       1                    2             0         0  37.764124 -122.456572
# 1       1                    2             0         0  37.784882 -122.438723
# 2       1                    2             0         0  37.766561 -122.389948
# 3       1                    0             0         1  37.764124 -122.456572
# 4       1                    0             0         1  37.784882 -122.438723
#
#    target_no_show  age_group_30-40  age_group_40-50  age_group_50-60  ...  \
# 0               0            False             True            False  ...
# 1               0            False             True            False  ...
# 2               0            False             True            False  ...
# 3               0             True            False            False  ...
# 4               0             True            False            False  ...
#
#    Specialty_Vascular Laboratory  \
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
#
#    Specialty_Vascular and Endovascular Surgery Clinic  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Specialty_Vasculitis Clinic  Specialty_Vision Optical Clinic  \
# 0                        False                            False
# 1                        False                            False
# 2                        False                            False
# 3                        False                            False
# 4                        False                            False
#
#    Specialty_Voice and Swallowing Center  Specialty_Weight Management Program  \
# 0                                  False                                False
# 1                                  False                                False
# 2                                  False                                False
# 3                                  False                                False
# 4                                  False                                False
#
#    Specialty_Women's Health Primary Care Clinic  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    Specialty_Women's Sports Medicine Center  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    Specialty_Women’s Center for Bladder & Pelvic Health  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Specialty_Young Women's Clinic
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                           False
#
# [5 rows x 330 columns]

# %%
# Print data types of all columns
print(data.dtypes)
# Out:
# Gender                                                    int64
# Alcohol Consumption                                       int64
# Hypertension                                              int64
# Diabetes                                                  int64
# lat                                                     float64
#                                                          ...
# Specialty_Weight Management Program                        bool
# Specialty_Women's Health Primary Care Clinic               bool
# Specialty_Women's Sports Medicine Center                   bool
# Specialty_Women’s Center for Bladder & Pelvic Health       bool
# Specialty_Young Women's Clinic                             bool
# Length: 330, dtype: object

# %%
data.info
# Out:
# <bound method DataFrame.info of         Gender  Alcohol Consumption  Hypertension  Diabetes        lat  \
# 0            1                    2             0         0  37.764124
# 1            1                    2             0         0  37.784882
# 2            1                    2             0         0  37.766561
# 3            1                    0             0         1  37.764124
# 4            1                    0             0         1  37.784882
# ...        ...                  ...           ...       ...        ...
# 132195       1                    1             0         0        NaN
# 132196       1                    2             0         0  37.764124
# 132197       1                    2             0         0  37.784882
# 132198       1                    2             0         0  37.766561
# 132199       1                    2             0         0        NaN
#
#               long  target_no_show  age_group_30-40  age_group_40-50  \
# 0      -122.456572               0            False             True
# 1      -122.438723               0            False             True
# 2      -122.389948               0            False             True
# 3      -122.456572               0             True            False
# 4      -122.438723               0             True            False
# ...            ...             ...              ...              ...
# 132195         NaN               0            False            False
# 132196 -122.456572               0            False             True
# 132197 -122.438723               0            False             True
# 132198 -122.389948               0            False             True
# 132199         NaN               0             True            False
#
#         age_group_50-60  ...  Specialty_Vascular Laboratory  \
# 0                 False  ...                          False
# 1                 False  ...                          False
# 2                 False  ...                          False
# 3                 False  ...                          False
# 4                 False  ...                          False
# ...                 ...  ...                            ...
# 132195             True  ...                          False
# 132196            False  ...                          False
# 132197            False  ...                          False
# 132198            False  ...                          False
# 132199            False  ...                          False
#
#         Specialty_Vascular and Endovascular Surgery Clinic  \
# 0                                                   False
# 1                                                   False
# 2                                                   False
# 3                                                   False
# 4                                                   False
# ...                                                   ...
# 132195                                              False
# 132196                                              False
# 132197                                              False
# 132198                                              False
# 132199                                              False
#
#         Specialty_Vasculitis Clinic  Specialty_Vision Optical Clinic  \
# 0                             False                            False
# 1                             False                            False
# 2                             False                            False
# 3                             False                            False
# 4                             False                            False
# ...                             ...                              ...
# 132195                        False                            False
# 132196                        False                            False
# 132197                        False                            False
# 132198                        False                            False
# 132199                        False                            False
#
#         Specialty_Voice and Swallowing Center  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ...                                       ...
# 132195                                  False
# 132196                                  False
# 132197                                  False
# 132198                                  False
# 132199                                  False
#
#         Specialty_Weight Management Program  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
# ...                                     ...
# 132195                                False
# 132196                                False
# 132197                                False
# 132198                                False
# 132199                                False
#
#         Specialty_Women's Health Primary Care Clinic  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
# ...                                              ...
# 132195                                         False
# 132196                                         False
# 132197                                         False
# 132198                                         False
# 132199                                         False
#
#         Specialty_Women's Sports Medicine Center  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 132195                                     False
# 132196                                     False
# 132197                                     False
# 132198                                     False
# 132199                                     False
#
#         Specialty_Women’s Center for Bladder & Pelvic Health  \
# 0                                                   False
# 1                                                   False
# 2                                                   False
# 3                                                   False
# 4                                                   False
# ...                                                   ...
# 132195                                              False
# 132196                                              False
# 132197                                              False
# 132198                                              False
# 132199                                              False
#
#         Specialty_Young Women's Clinic
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
# ...                                ...
# 132195                           False
# 132196                           False
# 132197                           False
# 132198                           False
# 132199                           False
#
# [132200 rows x 330 columns]>

# %%
# Create independent and Dependent Features
columns = data.columns.tolist()
# Filter the columns to remove data we do not want
columns = [c for c in columns if c not in ["target_no_show"]]
# Store the variable we are predicting
target = "target_no_show"

# Define a random state
state = np.random.RandomState(42)
X = data[columns]
Y = data[target]
X_outliers = state.uniform(low=0, high=1, size=(X.shape[0], X.shape[1]))
# Print the shapes of X & Y
print(X.shape)
print(Y.shape)
# Out:
# (132200, 329)
# (132200,)

# %%
# Remove rows with any missing values
data_cleaned = data.dropna()

# Check if there are still any missing values
data_cleaned.isnull().values.any()
# Out:
# False

# %%
count_classes = pd. value_counts(data[ 'target_no_show'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt. title("No_Show Distribution")
plt. xticks(range(2), LABELS)
plt. xlabel("target_no_show")
plt. ylabel ("Frequency")
# Out:
# /var/folders/0z/lpdq6xc50fb_51rn5s1nddzh0000gn/T/ipykernel_30311/2461647304.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   count_classes = pd. value_counts(data[ 'target_no_show'], sort = True)
# Text(0, 0.5, 'Frequency')

# %%
## Get the Fraud and the normal dataset
Shows = data[data ['target_no_show']==1]
No_Shows = data[data['target_no_show']==0]

# %%
print(Shows.shape,No_Shows.shape)
# Out:
# (5350, 330) (126850, 330)

# %%
from imblearn.under_sampling import NearMiss

# %%
from imblearn.under_sampling import RandomUnderSampler

# Initialize the RandomUnderSampler
rus = RandomUnderSampler(random_state=42)

# Fit and resample the data
X_res, y_res = rus.fit_resample(X, Y)

# Check the new shape of X and y
print(X_res.shape)
print(y_res.shape)
# Out:
# (10700, 329)
# (10700,)

# %%
from collections import Counter

# Print the original dataset class distribution
print('Original dataset shape:', Counter(Y))

# Print the resampled dataset class distribution
print('Resampled dataset shape:', Counter(y_res))
# Out:
# Original dataset shape: Counter({0: 126850, 1: 5350})
# Resampled dataset shape: Counter({0: 5350, 1: 5350})

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
from collections import Counter
import matplotlib.pyplot as plt

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.3, random_state=RANDOM_SEED)

# Initialize the classifier
clf = RandomForestClassifier(random_state=RANDOM_SEED)

# Train the classifier
clf.fit(X_train, y_train)

# Make predictions
y_pred = clf.predict(X_test)

# Print the classification report
print('Classification Report:\n', classification_report(y_test, y_pred, target_names=LABELS))

# Print the confusion matrix
print('Confusion Matrix:\n', confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#         Show       0.83      0.73      0.78      1630
#      No Show       0.75      0.85      0.80      1580
#
#     accuracy                           0.79      3210
#    macro avg       0.79      0.79      0.79      3210
# weighted avg       0.79      0.79      0.79      3210
#
# Confusion Matrix:
#  [[1188  442]
#  [ 238 1342]]

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import randint

# Define the parameter grid for RandomizedSearchCV
param_dist = {
    'n_estimators': randint(50, 300),  # Number of trees in the forest
    'max_depth': randint(5, 50),       # Maximum depth of the tree
    'min_samples_split': randint(2, 20), # Minimum number of samples required to split an internal node
    'min_samples_leaf': randint(1, 20),  # Minimum number of samples required to be at a leaf node
    'bootstrap': [True, False]          # Whether bootstrap samples are used when building trees
}

# Initialize the RandomForestClassifier
rf = RandomForestClassifier(random_state=RANDOM_SEED)

# Set up RandomizedSearchCV
random_search = RandomizedSearchCV(
    rf, param_distributions=param_dist, 
    n_iter=100,  # Number of parameter settings to sample
    cv=5,        # Number of cross-validation folds
    verbose=2,   # Verbosity level
    n_jobs=-1,   # Use all available cores
    random_state=RANDOM_SEED
)

# Fit RandomizedSearchCV
random_search.fit(X_train, y_train)

# Print the best parameters and score
print("Best Parameters:\n", random_search.best_params_)
print("Best Score:\n", random_search.best_score_)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END bootstrap=True, max_depth=33, min_samples_leaf=15, min_samples_split=12, n_estimators=121; total time=   1.5s
# [CV] END bootstrap=True, max_depth=33, min_samples_leaf=15, min_samples_split=12, n_estimators=121; total time=   1.6s
# [CV] END bootstrap=True, max_depth=33, min_samples_leaf=15, min_samples_split=12, n_estimators=121; total time=   1.6s
# [CV] END bootstrap=True, max_depth=33, min_samples_leaf=15, min_samples_split=12, n_estimators=121; total time=   1.6s
# [CV] END bootstrap=True, max_depth=33, min_samples_leaf=15, min_samples_split=12, n_estimators=121; total time=   1.6s
# [CV] END bootstrap=True, max_depth=25, min_samples_leaf=7, min_samples_split=12, n_estimators=252; total time=   4.3s
# [CV] END bootstrap=True, max_depth=25, min_samples_leaf=7, min_samples_split=12, n_estimators=252; total time=   4.4s
# [CV] END bootstrap=True, max_depth=25, min_samples_leaf=7, min_samples_split=12, n_estimators=252; total time=   4.4s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=12, min_samples_split=7, n_estimators=179; total time=   1.6s
# [CV] END bootstrap=True, max_depth=25, min_samples_leaf=7, min_samples_split=12, n_estimators=252; total time=   4.9s
# [CV] END bootstrap=True, max_depth=25, min_samples_leaf=7, min_samples_split=12, n_estimators=252; total time=   5.1s
# [CV] END bootstrap=False, max_depth=40, min_samples_leaf=8, min_samples_split=4, n_estimators=199; total time=   5.4s
# [CV] END bootstrap=False, max_depth=40, min_samples_leaf=8, min_samples_split=4, n_estimators=199; total time=   5.3s
# [CV] END bootstrap=False, max_depth=40, min_samples_leaf=8, min_samples_split=4, n_estimators=199; total time=   5.3s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=12, min_samples_split=7, n_estimators=179; total time=   1.7s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=12, min_samples_split=7, n_estimators=179; total time=   1.6s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=12, min_samples_split=7, n_estimators=179; total time=   1.6s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=12, min_samples_split=7, n_estimators=179; total time=   1.6s
# [CV] END bootstrap=False, max_depth=40, min_samples_leaf=8, min_samples_split=4, n_estimators=199; total time=   4.9s
# [CV] END bootstrap=False, max_depth=40, min_samples_leaf=8, min_samples_split=4, n_estimators=199; total time=   4.9s
# [CV] END bootstrap=False, max_depth=25, min_samples_leaf=1, min_samples_split=13, n_estimators=107; total time=   3.1s
# [CV] END bootstrap=False, max_depth=25, min_samples_leaf=1, min_samples_split=13, n_estimators=107; total time=   3.2s
# [CV] END bootstrap=False, max_depth=25, min_samples_leaf=1, min_samples_split=13, n_estimators=107; total time=   3.0s
# [CV] END bootstrap=False, max_depth=25, min_samples_leaf=1, min_samples_split=13, n_estimators=107; total time=   3.0s
# [CV] END bootstrap=False, max_depth=25, min_samples_leaf=1, min_samples_split=13, n_estimators=107; total time=   3.0s
# [CV] END bootstrap=False, max_depth=48, min_samples_leaf=17, min_samples_split=11, n_estimators=269; total time=   4.5s
# [CV] END bootstrap=False, max_depth=48, min_samples_leaf=17, min_samples_split=11, n_estimators=269; total time=   4.5s
# [CV] END bootstrap=False, max_depth=48, min_samples_leaf=17, min_samples_split=11, n_estimators=269; total time=   4.5s
# [CV] END bootstrap=False, max_depth=48, min_samples_leaf=17, min_samples_split=11, n_estimators=269; total time=   4.7s
# [CV] END bootstrap=False, max_depth=48, min_samples_leaf=17, min_samples_split=11, n_estimators=269; total time=   4.9s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=15, min_samples_split=16, n_estimators=239; total time=   4.2s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=15, min_samples_split=16, n_estimators=239; total time=   4.3s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=15, min_samples_split=16, n_estimators=239; total time=   4.3s
# [CV] END bootstrap=True, max_depth=48, min_samples_leaf=3, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, max_depth=25, min_samples_leaf=9, min_samples_split=8, n_estimators=67; total time=   1.0s
# [CV] END bootstrap=True, max_depth=25, min_samples_leaf=9, min_samples_split=8, n_estimators=67; total time=   1.0s
# [CV] END bootstrap=True, max_depth=48, min_samples_leaf=3, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=15, min_samples_split=16, n_estimators=239; total time=   4.1s
# [CV] END bootstrap=True, max_depth=48, min_samples_leaf=3, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, max_depth=48, min_samples_leaf=3, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, max_depth=48, min_samples_leaf=3, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END bootstrap=True, max_depth=25, min_samples_leaf=9, min_samples_split=8, n_estimators=67; total time=   1.1s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=15, min_samples_split=16, n_estimators=239; total time=   4.0s
# [CV] END bootstrap=True, max_depth=25, min_samples_leaf=9, min_samples_split=8, n_estimators=67; total time=   1.1s
# [CV] END bootstrap=True, max_depth=25, min_samples_leaf=9, min_samples_split=8, n_estimators=67; total time=   1.0s
# [CV] END bootstrap=False, max_depth=29, min_samples_leaf=14, min_samples_split=19, n_estimators=299; total time=   5.2s
# [CV] END bootstrap=False, max_depth=29, min_samples_leaf=14, min_samples_split=19, n_estimators=299; total time=   5.2s
# [CV] END bootstrap=False, max_depth=29, min_samples_leaf=14, min_samples_split=19, n_estimators=299; total time=   5.2s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=16, n_estimators=237; total time=   4.9s
# [CV] END bootstrap=False, max_depth=29, min_samples_leaf=14, min_samples_split=19, n_estimators=299; total time=   5.3s
# [CV] END bootstrap=False, max_depth=29, min_samples_leaf=14, min_samples_split=19, n_estimators=299; total time=   5.3s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=16, n_estimators=237; total time=   4.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=16, n_estimators=237; total time=   4.9s
# [CV] END bootstrap=True, max_depth=48, min_samples_leaf=8, min_samples_split=16, n_estimators=84; total time=   1.4s
# [CV] END bootstrap=True, max_depth=48, min_samples_leaf=8, min_samples_split=16, n_estimators=84; total time=   1.4s
# [CV] END bootstrap=True, max_depth=48, min_samples_leaf=8, min_samples_split=16, n_estimators=84; total time=   1.4s
# [CV] END bootstrap=True, max_depth=48, min_samples_leaf=8, min_samples_split=16, n_estimators=84; total time=   1.4s
# [CV] END bootstrap=True, max_depth=48, min_samples_leaf=8, min_samples_split=16, n_estimators=84; total time=   1.4s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=6, min_samples_split=11, n_estimators=53; total time=   0.6s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=6, min_samples_split=11, n_estimators=53; total time=   0.7s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=6, min_samples_split=11, n_estimators=53; total time=   0.6s
# [CV] END bootstrap=False, max_depth=21, min_samples_leaf=4, min_samples_split=19, n_estimators=153; total time=   3.4s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=6, min_samples_split=11, n_estimators=53; total time=   0.6s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=6, min_samples_split=11, n_estimators=53; total time=   0.5s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=16, n_estimators=237; total time=   4.9s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=16, n_estimators=237; total time=   4.9s
# [CV] END bootstrap=False, max_depth=21, min_samples_leaf=4, min_samples_split=19, n_estimators=153; total time=   3.4s
# [CV] END bootstrap=False, max_depth=21, min_samples_leaf=4, min_samples_split=19, n_estimators=153; total time=   3.4s
# [CV] END bootstrap=False, max_depth=21, min_samples_leaf=4, min_samples_split=19, n_estimators=153; total time=   3.7s
# [CV] END bootstrap=False, max_depth=21, min_samples_leaf=4, min_samples_split=19, n_estimators=153; total time=   3.4s
# [CV] END bootstrap=False, max_depth=40, min_samples_leaf=14, min_samples_split=17, n_estimators=64; total time=   1.2s
# [CV] END bootstrap=False, max_depth=40, min_samples_leaf=14, min_samples_split=17, n_estimators=64; total time=   1.2s
# [CV] END bootstrap=False, max_depth=40, min_samples_leaf=14, min_samples_split=17, n_estimators=64; total time=   1.2s
# [CV] END bootstrap=False, max_depth=40, min_samples_leaf=14, min_samples_split=17, n_estimators=64; total time=   1.2s
# [CV] END bootstrap=False, max_depth=40, min_samples_leaf=14, min_samples_split=17, n_estimators=64; total time=   1.3s
# [CV] END bootstrap=False, max_depth=33, min_samples_leaf=18, min_samples_split=13, n_estimators=211; total time=   3.4s
# [CV] END bootstrap=False, max_depth=33, min_samples_leaf=18, min_samples_split=13, n_estimators=211; total time=   3.4s
# [CV] END bootstrap=False, max_depth=33, min_samples_leaf=18, min_samples_split=13, n_estimators=211; total time=   3.3s
# [CV] END bootstrap=False, max_depth=33, min_samples_leaf=18, min_samples_split=13, n_estimators=211; total time=   3.4s
# [CV] END bootstrap=False, max_depth=33, min_samples_leaf=18, min_samples_split=13, n_estimators=211; total time=   3.4s
# [CV] END bootstrap=False, max_depth=18, min_samples_leaf=8, min_samples_split=17, n_estimators=286; total time=   5.2s
# [CV] END bootstrap=False, max_depth=28, min_samples_leaf=13, min_samples_split=10, n_estimators=206; total time=   3.6s
# [CV] END bootstrap=False, max_depth=28, min_samples_leaf=13, min_samples_split=10, n_estimators=206; total time=   3.8s
# [CV] END bootstrap=False, max_depth=28, min_samples_leaf=13, min_samples_split=10, n_estimators=206; total time=   3.8s
# [CV] END bootstrap=False, max_depth=18, min_samples_leaf=8, min_samples_split=17, n_estimators=286; total time=   5.1s
# [CV] END bootstrap=False, max_depth=18, min_samples_leaf=8, min_samples_split=17, n_estimators=286; total time=   5.3s
# [CV] END bootstrap=False, max_depth=18, min_samples_leaf=8, min_samples_split=17, n_estimators=286; total time=   5.2s
# [CV] END bootstrap=False, max_depth=18, min_samples_leaf=8, min_samples_split=17, n_estimators=286; total time=   5.2s
# [CV] END bootstrap=True, max_depth=49, min_samples_leaf=1, min_samples_split=8, n_estimators=58; total time=   1.7s
# [CV] END bootstrap=True, max_depth=49, min_samples_leaf=1, min_samples_split=8, n_estimators=58; total time=   1.6s
# [CV] END bootstrap=True, max_depth=49, min_samples_leaf=1, min_samples_split=8, n_estimators=58; total time=   1.7s
# [CV] END bootstrap=True, max_depth=49, min_samples_leaf=1, min_samples_split=8, n_estimators=58; total time=   1.7s
# [CV] END bootstrap=True, max_depth=49, min_samples_leaf=1, min_samples_split=8, n_estimators=58; total time=   1.6s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=12, min_samples_split=9, n_estimators=265; total time=   2.0s
# [CV] END bootstrap=False, max_depth=28, min_samples_leaf=13, min_samples_split=10, n_estimators=206; total time=   3.8s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=12, min_samples_split=9, n_estimators=265; total time=   1.9s
# [CV] END bootstrap=False, max_depth=28, min_samples_leaf=13, min_samples_split=10, n_estimators=206; total time=   3.8s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=12, min_samples_split=9, n_estimators=265; total time=   1.9s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=12, min_samples_split=9, n_estimators=265; total time=   1.9s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=12, min_samples_split=9, n_estimators=265; total time=   1.9s
# [CV] END bootstrap=True, max_depth=15, min_samples_leaf=19, min_samples_split=18, n_estimators=185; total time=   1.9s
# [CV] END bootstrap=True, max_depth=15, min_samples_leaf=19, min_samples_split=18, n_estimators=185; total time=   1.9s
# [CV] END bootstrap=True, max_depth=15, min_samples_leaf=19, min_samples_split=18, n_estimators=185; total time=   2.0s
# [CV] END bootstrap=True, max_depth=15, min_samples_leaf=19, min_samples_split=18, n_estimators=185; total time=   2.0s
# [CV] END bootstrap=True, max_depth=15, min_samples_leaf=19, min_samples_split=18, n_estimators=185; total time=   2.0s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=7, min_samples_split=10, n_estimators=121; total time=   2.0s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=7, min_samples_split=10, n_estimators=121; total time=   2.0s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=7, min_samples_split=10, n_estimators=121; total time=   2.0s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=7, min_samples_split=10, n_estimators=121; total time=   2.1s
# [CV] END bootstrap=True, max_depth=45, min_samples_leaf=7, min_samples_split=10, n_estimators=121; total time=   2.0s
# [CV] END bootstrap=True, max_depth=39, min_samples_leaf=1, min_samples_split=6, n_estimators=283; total time=   7.7s
# [CV] END bootstrap=True, max_depth=39, min_samples_leaf=1, min_samples_split=6, n_estimators=283; total time=   7.7s
# [CV] END bootstrap=True, max_depth=39, min_samples_leaf=1, min_samples_split=6, n_estimators=283; total time=   7.8s
# [CV] END bootstrap=True, max_depth=39, min_samples_leaf=1, min_samples_split=6, n_estimators=283; total time=   7.9s
# [CV] END bootstrap=True, max_depth=39, min_samples_leaf=1, min_samples_split=6, n_estimators=283; total time=   7.8s
# [CV] END bootstrap=True, max_depth=28, min_samples_leaf=5, min_samples_split=4, n_estimators=221; total time=   4.0s
# [CV] END bootstrap=True, max_depth=28, min_samples_leaf=5, min_samples_split=4, n_estimators=221; total time=   4.1s
# [CV] END bootstrap=True, max_depth=28, min_samples_leaf=5, min_samples_split=4, n_estimators=221; total time=   4.1s
# [CV] END bootstrap=False, max_depth=38, min_samples_leaf=1, min_samples_split=17, n_estimators=296; total time=  10.7s
# [CV] END bootstrap=False, max_depth=38, min_samples_leaf=1, min_samples_split=17, n_estimators=296; total time=  11.0s
# [CV] END bootstrap=True, max_depth=28, min_samples_leaf=5, min_samples_split=4, n_estimators=221; total time=   4.3s
# [CV] END bootstrap=True, max_depth=28, min_samples_leaf=5, min_samples_split=4, n_estimators=221; total time=   4.2s
# [CV] END bootstrap=False, max_depth=38, min_samples_leaf=1, min_samples_split=17, n_estimators=296; total time=  11.3s
# [CV] END bootstrap=True, max_depth=18, min_samples_leaf=3, min_samples_split=2, n_estimators=54; total time=   1.0s
# [CV] END bootstrap=False, max_depth=38, min_samples_leaf=1, min_samples_split=17, n_estimators=296; total time=  11.1s
# [CV] END bootstrap=True, max_depth=18, min_samples_leaf=3, min_samples_split=2, n_estimators=54; total time=   1.0s
# [CV] END bootstrap=False, max_depth=38, min_samples_leaf=1, min_samples_split=17, n_estimators=296; total time=  11.2s
# [CV] END bootstrap=True, max_depth=18, min_samples_leaf=3, min_samples_split=2, n_estimators=54; total time=   0.9s
# [CV] END bootstrap=True, max_depth=18, min_samples_leaf=3, min_samples_split=2, n_estimators=54; total time=   1.0s
# [CV] END bootstrap=True, max_depth=18, min_samples_leaf=3, min_samples_split=2, n_estimators=54; total time=   1.0s
# [CV] END bootstrap=False, max_depth=26, min_samples_leaf=3, min_samples_split=2, n_estimators=276; total time=   7.5s
# [CV] END bootstrap=False, max_depth=26, min_samples_leaf=3, min_samples_split=2, n_estimators=276; total time=   7.5s
# [CV] END bootstrap=False, max_depth=26, min_samples_leaf=3, min_samples_split=2, n_estimators=276; total time=   7.5s
# [CV] END bootstrap=False, max_depth=26, min_samples_leaf=3, min_samples_split=2, n_estimators=276; total time=   7.4s
# [CV] END bootstrap=False, max_depth=26, min_samples_leaf=3, min_samples_split=2, n_estimators=276; total time=   7.5s
# [CV] END bootstrap=False, max_depth=18, min_samples_leaf=7, min_samples_split=10, n_estimators=256; total time=   4.8s
# [CV] END bootstrap=False, max_depth=18, min_samples_leaf=7, min_samples_split=10, n_estimators=256; total time=   4.9s
# [CV] END bootstrap=False, max_depth=18, min_samples_leaf=7, min_samples_split=10, n_estimators=256; total time=   5.0s
# [CV] END bootstrap=False, max_depth=18, min_samples_leaf=7, min_samples_split=10, n_estimators=256; total time=   5.0s
# [CV] END bootstrap=True, max_depth=36, min_samples_leaf=7, min_samples_split=18, n_estimators=101; total time=   1.7s
# [CV] END bootstrap=False, max_depth=18, min_samples_leaf=7, min_samples_split=10, n_estimators=256; total time=   5.0s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=10, min_samples_split=14, n_estimators=228; total time=   3.2s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=10, min_samples_split=14, n_estimators=228; total time=   3.2s
# [CV] END bootstrap=True, max_depth=36, min_samples_leaf=7, min_samples_split=18, n_estimators=101; total time=   1.7s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=10, min_samples_split=14, n_estimators=228; total time=   3.2s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=10, min_samples_split=14, n_estimators=228; total time=   3.3s
# [CV] END bootstrap=True, max_depth=30, min_samples_leaf=10, min_samples_split=14, n_estimators=228; total time=   3.7s
# [CV] END bootstrap=True, max_depth=36, min_samples_leaf=7, min_samples_split=18, n_estimators=101; total time=   2.1s
# [CV] END bootstrap=True, max_depth=36, min_samples_leaf=7, min_samples_split=18, n_estimators=101; total time=   2.0s
# [CV] END bootstrap=True, max_depth=36, min_samples_leaf=7, min_samples_split=18, n_estimators=101; total time=   2.1s
# [CV] END bootstrap=True, max_depth=49, min_samples_leaf=15, min_samples_split=12, n_estimators=78; total time=   1.1s
# [CV] END bootstrap=True, max_depth=49, min_samples_leaf=15, min_samples_split=12, n_estimators=78; total time=   1.0s
# [CV] END bootstrap=True, max_depth=49, min_samples_leaf=15, min_samples_split=12, n_estimators=78; total time=   1.0s
# [CV] END bootstrap=True, max_depth=49, min_samples_leaf=15, min_samples_split=12, n_estimators=78; total time=   1.0s
# [CV] END bootstrap=True, max_depth=49, min_samples_leaf=15, min_samples_split=12, n_estimators=78; total time=   1.1s
# [CV] END bootstrap=True, max_depth=36, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   4.2s
# [CV] END bootstrap=True, max_depth=36, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   4.2s
# [CV] END bootstrap=True, max_depth=36, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   4.2s
# [CV] END bootstrap=True, max_depth=36, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   4.3s
# [CV] END bootstrap=True, max_depth=36, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   3.9s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=12, min_samples_split=13, n_estimators=133; total time=   1.4s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=12, min_samples_split=13, n_estimators=133; total time=   1.4s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=12, min_samples_split=13, n_estimators=133; total time=   1.3s
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=7, min_samples_split=3, n_estimators=219; total time=   4.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=12, min_samples_split=13, n_estimators=133; total time=   1.3s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=12, min_samples_split=13, n_estimators=133; total time=   1.4s
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=7, min_samples_split=3, n_estimators=219; total time=   3.9s
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=7, min_samples_split=3, n_estimators=219; total time=   3.9s
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=7, min_samples_split=3, n_estimators=219; total time=   3.9s
# [CV] END bootstrap=False, max_depth=17, min_samples_leaf=7, min_samples_split=3, n_estimators=219; total time=   3.9s
# [CV] END bootstrap=True, max_depth=31, min_samples_leaf=13, min_samples_split=10, n_estimators=52; total time=   0.7s
# [CV] END bootstrap=True, max_depth=31, min_samples_leaf=13, min_samples_split=10, n_estimators=52; total time=   0.7s
# [CV] END bootstrap=True, max_depth=31, min_samples_leaf=13, min_samples_split=10, n_estimators=52; total time=   0.7s
# [CV] END bootstrap=True, max_depth=31, min_samples_leaf=13, min_samples_split=10, n_estimators=52; total time=   0.7s
# [CV] END bootstrap=True, max_depth=31, min_samples_leaf=13, min_samples_split=10, n_estimators=52; total time=   0.7s
# [CV] END bootstrap=False, max_depth=15, min_samples_leaf=7, min_samples_split=2, n_estimators=178; total time=   3.0s
# [CV] END bootstrap=False, max_depth=15, min_samples_leaf=7, min_samples_split=2, n_estimators=178; total time=   3.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=8, min_samples_split=10, n_estimators=111; total time=   1.2s
# [CV] END bootstrap=False, max_depth=15, min_samples_leaf=7, min_samples_split=2, n_estimators=178; total time=   3.0s
# [CV] END bootstrap=False, max_depth=15, min_samples_leaf=7, min_samples_split=2, n_estimators=178; total time=   3.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=8, min_samples_split=10, n_estimators=111; total time=   1.2s
# [CV] END bootstrap=False, max_depth=15, min_samples_leaf=7, min_samples_split=2, n_estimators=178; total time=   3.0s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=8, min_samples_split=10, n_estimators=111; total time=   1.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=8, min_samples_split=10, n_estimators=111; total time=   1.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=8, min_samples_split=10, n_estimators=111; total time=   1.2s
# [CV] END bootstrap=True, max_depth=37, min_samples_leaf=19, min_samples_split=11, n_estimators=221; total time=   2.5s
# [CV] END bootstrap=True, max_depth=37, min_samples_leaf=19, min_samples_split=11, n_estimators=221; total time=   2.5s
# [CV] END bootstrap=False, max_depth=19, min_samples_leaf=9, min_samples_split=18, n_estimators=111; total time=   2.2s
# [CV] END bootstrap=False, max_depth=19, min_samples_leaf=9, min_samples_split=18, n_estimators=111; total time=   2.1s
# [CV] END bootstrap=True, max_depth=37, min_samples_leaf=19, min_samples_split=11, n_estimators=221; total time=   2.6s
# [CV] END bootstrap=True, max_depth=37, min_samples_leaf=19, min_samples_split=11, n_estimators=221; total time=   2.7s
# [CV] END bootstrap=True, max_depth=37, min_samples_leaf=19, min_samples_split=11, n_estimators=221; total time=   2.5s
# [CV] END bootstrap=False, max_depth=19, min_samples_leaf=9, min_samples_split=18, n_estimators=111; total time=   2.3s
# [CV] END bootstrap=False, max_depth=19, min_samples_leaf=9, min_samples_split=18, n_estimators=111; total time=   2.3s
# [CV] END bootstrap=False, max_depth=19, min_samples_leaf=9, min_samples_split=18, n_estimators=111; total time=   2.2s
# [CV] END bootstrap=True, max_depth=16, min_samples_leaf=7, min_samples_split=3, n_estimators=180; total time=   2.5s
# [CV] END bootstrap=True, max_depth=16, min_samples_leaf=7, min_samples_split=3, n_estimators=180; total time=   2.7s
# [CV] END bootstrap=True, max_depth=16, min_samples_leaf=7, min_samples_split=3, n_estimators=180; total time=   2.5s
# [CV] END bootstrap=True, max_depth=16, min_samples_leaf=7, min_samples_split=3, n_estimators=180; total time=   2.8s
# [CV] END bootstrap=True, max_depth=16, min_samples_leaf=7, min_samples_split=3, n_estimators=180; total time=   2.6s
# [CV] END bootstrap=True, max_depth=41, min_samples_leaf=17, min_samples_split=18, n_estimators=236; total time=   2.8s
# [CV] END bootstrap=True, max_depth=41, min_samples_leaf=17, min_samples_split=18, n_estimators=236; total time=   2.7s
# [CV] END bootstrap=True, max_depth=41, min_samples_leaf=17, min_samples_split=18, n_estimators=236; total time=   2.7s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=2, min_samples_split=6, n_estimators=273; total time=   2.1s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=2, min_samples_split=6, n_estimators=273; total time=   2.1s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=2, min_samples_split=6, n_estimators=273; total time=   2.1s
# [CV] END bootstrap=True, max_depth=41, min_samples_leaf=17, min_samples_split=18, n_estimators=236; total time=   2.8s
# [CV] END bootstrap=True, max_depth=41, min_samples_leaf=17, min_samples_split=18, n_estimators=236; total time=   2.7s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=19, min_samples_split=3, n_estimators=102; total time=   0.8s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=2, min_samples_split=6, n_estimators=273; total time=   2.2s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=19, min_samples_split=3, n_estimators=102; total time=   0.8s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=19, min_samples_split=3, n_estimators=102; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=19, min_samples_split=3, n_estimators=102; total time=   0.8s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=19, min_samples_split=3, n_estimators=102; total time=   0.8s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=2, min_samples_split=6, n_estimators=273; total time=   2.3s
# [CV] END bootstrap=True, max_depth=21, min_samples_leaf=6, min_samples_split=6, n_estimators=165; total time=   2.5s
# [CV] END bootstrap=True, max_depth=21, min_samples_leaf=6, min_samples_split=6, n_estimators=165; total time=   2.7s
# [CV] END bootstrap=True, max_depth=21, min_samples_leaf=6, min_samples_split=6, n_estimators=165; total time=   2.6s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=6, min_samples_split=5, n_estimators=232; total time=   5.3s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=6, min_samples_split=5, n_estimators=232; total time=   5.4s
# [CV] END bootstrap=True, max_depth=21, min_samples_leaf=6, min_samples_split=6, n_estimators=165; total time=   2.6s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=6, min_samples_split=5, n_estimators=232; total time=   5.5s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=6, min_samples_split=5, n_estimators=232; total time=   5.5s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=6, min_samples_split=5, n_estimators=232; total time=   5.4s
# [CV] END bootstrap=True, max_depth=21, min_samples_leaf=6, min_samples_split=6, n_estimators=165; total time=   2.5s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=11, min_samples_split=17, n_estimators=193; total time=   2.3s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=6, min_samples_split=17, n_estimators=142; total time=   1.7s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=6, min_samples_split=17, n_estimators=142; total time=   1.8s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=6, min_samples_split=17, n_estimators=142; total time=   1.7s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=11, min_samples_split=17, n_estimators=193; total time=   2.4s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=11, min_samples_split=17, n_estimators=193; total time=   2.4s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=11, min_samples_split=17, n_estimators=193; total time=   2.5s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=11, min_samples_split=17, n_estimators=193; total time=   2.5s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=6, min_samples_split=17, n_estimators=142; total time=   1.8s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=6, min_samples_split=17, n_estimators=142; total time=   1.8s
# [CV] END bootstrap=True, max_depth=24, min_samples_leaf=4, min_samples_split=4, n_estimators=196; total time=   3.5s
# [CV] END bootstrap=True, max_depth=24, min_samples_leaf=4, min_samples_split=4, n_estimators=196; total time=   3.4s
# [CV] END bootstrap=True, max_depth=24, min_samples_leaf=4, min_samples_split=4, n_estimators=196; total time=   3.5s
# [CV] END bootstrap=True, max_depth=24, min_samples_leaf=4, min_samples_split=4, n_estimators=196; total time=   3.6s
# [CV] END bootstrap=True, max_depth=24, min_samples_leaf=4, min_samples_split=4, n_estimators=196; total time=   3.6s
# [CV] END bootstrap=False, max_depth=36, min_samples_leaf=7, min_samples_split=10, n_estimators=210; total time=   4.9s
# [CV] END bootstrap=False, max_depth=36, min_samples_leaf=7, min_samples_split=10, n_estimators=210; total time=   4.8s
# [CV] END bootstrap=False, max_depth=36, min_samples_leaf=7, min_samples_split=10, n_estimators=210; total time=   4.8s
# [CV] END bootstrap=False, max_depth=43, min_samples_leaf=18, min_samples_split=9, n_estimators=178; total time=   2.9s
# [CV] END bootstrap=False, max_depth=43, min_samples_leaf=18, min_samples_split=9, n_estimators=178; total time=   3.0s
# [CV] END bootstrap=False, max_depth=43, min_samples_leaf=18, min_samples_split=9, n_estimators=178; total time=   3.0s
# [CV] END bootstrap=False, max_depth=36, min_samples_leaf=7, min_samples_split=10, n_estimators=210; total time=   4.8s
# [CV] END bootstrap=False, max_depth=36, min_samples_leaf=7, min_samples_split=10, n_estimators=210; total time=   4.9s
# [CV] END bootstrap=True, max_depth=32, min_samples_leaf=18, min_samples_split=11, n_estimators=148; total time=   1.9s
# [CV] END bootstrap=True, max_depth=32, min_samples_leaf=18, min_samples_split=11, n_estimators=148; total time=   1.9s
# [CV] END bootstrap=False, max_depth=43, min_samples_leaf=18, min_samples_split=9, n_estimators=178; total time=   3.1s
# [CV] END bootstrap=True, max_depth=32, min_samples_leaf=18, min_samples_split=11, n_estimators=148; total time=   1.9s
# [CV] END bootstrap=False, max_depth=43, min_samples_leaf=18, min_samples_split=9, n_estimators=178; total time=   3.1s
# [CV] END bootstrap=True, max_depth=32, min_samples_leaf=18, min_samples_split=11, n_estimators=148; total time=   1.9s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=16, min_samples_split=18, n_estimators=51; total time=   0.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=16, min_samples_split=18, n_estimators=51; total time=   0.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=16, min_samples_split=18, n_estimators=51; total time=   0.8s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=16, min_samples_split=18, n_estimators=51; total time=   0.7s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=16, min_samples_split=18, n_estimators=51; total time=   0.8s
# [CV] END bootstrap=True, max_depth=32, min_samples_leaf=18, min_samples_split=11, n_estimators=148; total time=   1.8s
# [CV] END bootstrap=True, max_depth=16, min_samples_leaf=5, min_samples_split=6, n_estimators=209; total time=   3.0s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=9, min_samples_split=4, n_estimators=196; total time=   2.4s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=9, min_samples_split=4, n_estimators=196; total time=   2.5s
# [CV] END bootstrap=True, max_depth=16, min_samples_leaf=5, min_samples_split=6, n_estimators=209; total time=   3.1s
# [CV] END bootstrap=True, max_depth=16, min_samples_leaf=5, min_samples_split=6, n_estimators=209; total time=   3.1s
# [CV] END bootstrap=True, max_depth=16, min_samples_leaf=5, min_samples_split=6, n_estimators=209; total time=   3.1s
# [CV] END bootstrap=True, max_depth=16, min_samples_leaf=5, min_samples_split=6, n_estimators=209; total time=   3.1s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=9, min_samples_split=4, n_estimators=196; total time=   2.6s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=9, min_samples_split=4, n_estimators=196; total time=   2.6s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=9, min_samples_split=4, n_estimators=196; total time=   2.5s
# [CV] END bootstrap=False, max_depth=15, min_samples_leaf=17, min_samples_split=9, n_estimators=213; total time=   3.4s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=3, min_samples_split=2, n_estimators=201; total time=   4.7s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=3, min_samples_split=2, n_estimators=201; total time=   5.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=3, min_samples_split=2, n_estimators=201; total time=   4.8s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=3, min_samples_split=2, n_estimators=201; total time=   4.9s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=3, min_samples_split=2, n_estimators=201; total time=   4.9s
# [CV] END bootstrap=False, max_depth=15, min_samples_leaf=17, min_samples_split=9, n_estimators=213; total time=   3.3s
# [CV] END bootstrap=False, max_depth=15, min_samples_leaf=17, min_samples_split=9, n_estimators=213; total time=   3.3s
# [CV] END bootstrap=True, max_depth=29, min_samples_leaf=18, min_samples_split=15, n_estimators=131; total time=   1.7s
# [CV] END bootstrap=False, max_depth=15, min_samples_leaf=17, min_samples_split=9, n_estimators=213; total time=   3.5s
# [CV] END bootstrap=False, max_depth=15, min_samples_leaf=17, min_samples_split=9, n_estimators=213; total time=   3.4s
# [CV] END bootstrap=True, max_depth=29, min_samples_leaf=18, min_samples_split=15, n_estimators=131; total time=   1.7s
# [CV] END bootstrap=True, max_depth=29, min_samples_leaf=18, min_samples_split=15, n_estimators=131; total time=   1.7s
# [CV] END bootstrap=True, max_depth=29, min_samples_leaf=18, min_samples_split=15, n_estimators=131; total time=   1.7s
# [CV] END bootstrap=True, max_depth=29, min_samples_leaf=18, min_samples_split=15, n_estimators=131; total time=   1.7s
# [CV] END bootstrap=False, max_depth=44, min_samples_leaf=3, min_samples_split=17, n_estimators=266; total time=   7.9s
# [CV] END bootstrap=False, max_depth=44, min_samples_leaf=3, min_samples_split=17, n_estimators=266; total time=   8.0s
# [CV] END bootstrap=False, max_depth=44, min_samples_leaf=3, min_samples_split=17, n_estimators=266; total time=   8.1s
# [CV] END bootstrap=False, max_depth=44, min_samples_leaf=3, min_samples_split=17, n_estimators=266; total time=   8.1s
# [CV] END bootstrap=False, max_depth=44, min_samples_leaf=3, min_samples_split=17, n_estimators=266; total time=   8.1s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=1, min_samples_split=15, n_estimators=70; total time=   0.8s
# [CV] END bootstrap=False, max_depth=39, min_samples_leaf=16, min_samples_split=10, n_estimators=277; total time=   5.0s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=1, min_samples_split=15, n_estimators=70; total time=   0.8s
# [CV] END bootstrap=False, max_depth=39, min_samples_leaf=16, min_samples_split=10, n_estimators=277; total time=   4.8s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=1, min_samples_split=15, n_estimators=70; total time=   0.8s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=1, min_samples_split=15, n_estimators=70; total time=   0.9s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=1, min_samples_split=15, n_estimators=70; total time=   0.9s
# [CV] END bootstrap=False, max_depth=39, min_samples_leaf=16, min_samples_split=10, n_estimators=277; total time=   4.7s
# [CV] END bootstrap=False, max_depth=39, min_samples_leaf=16, min_samples_split=10, n_estimators=277; total time=   4.8s
# [CV] END bootstrap=False, max_depth=39, min_samples_leaf=16, min_samples_split=10, n_estimators=277; total time=   5.0s
# [CV] END bootstrap=True, max_depth=37, min_samples_leaf=16, min_samples_split=13, n_estimators=236; total time=   2.9s
# [CV] END bootstrap=False, max_depth=24, min_samples_leaf=8, min_samples_split=8, n_estimators=244; total time=   5.0s
# [CV] END bootstrap=False, max_depth=24, min_samples_leaf=8, min_samples_split=8, n_estimators=244; total time=   5.2s
# [CV] END bootstrap=False, max_depth=24, min_samples_leaf=8, min_samples_split=8, n_estimators=244; total time=   5.2s
# [CV] END bootstrap=False, max_depth=24, min_samples_leaf=8, min_samples_split=8, n_estimators=244; total time=   5.1s
# [CV] END bootstrap=False, max_depth=24, min_samples_leaf=8, min_samples_split=8, n_estimators=244; total time=   5.3s
# [CV] END bootstrap=True, max_depth=37, min_samples_leaf=16, min_samples_split=13, n_estimators=236; total time=   3.1s
# [CV] END bootstrap=True, max_depth=37, min_samples_leaf=16, min_samples_split=13, n_estimators=236; total time=   3.2s
# [CV] END bootstrap=True, max_depth=37, min_samples_leaf=16, min_samples_split=13, n_estimators=236; total time=   3.0s
# [CV] END bootstrap=True, max_depth=37, min_samples_leaf=16, min_samples_split=13, n_estimators=236; total time=   3.0s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=2, min_samples_split=2, n_estimators=77; total time=   1.1s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=2, min_samples_split=2, n_estimators=77; total time=   1.1s
# [CV] END bootstrap=True, max_depth=26, min_samples_leaf=14, min_samples_split=7, n_estimators=279; total time=   3.8s
# [CV] END bootstrap=True, max_depth=26, min_samples_leaf=14, min_samples_split=7, n_estimators=279; total time=   3.8s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=2, min_samples_split=2, n_estimators=77; total time=   1.2s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=2, min_samples_split=2, n_estimators=77; total time=   1.2s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=2, min_samples_split=2, n_estimators=77; total time=   1.2s
# [CV] END bootstrap=True, max_depth=26, min_samples_leaf=14, min_samples_split=7, n_estimators=279; total time=   3.8s
# [CV] END bootstrap=True, max_depth=26, min_samples_leaf=14, min_samples_split=7, n_estimators=279; total time=   3.9s
# [CV] END bootstrap=True, max_depth=26, min_samples_leaf=14, min_samples_split=7, n_estimators=279; total time=   3.9s
# [CV] END bootstrap=True, max_depth=37, min_samples_leaf=5, min_samples_split=17, n_estimators=196; total time=   3.6s
# [CV] END bootstrap=True, max_depth=37, min_samples_leaf=5, min_samples_split=17, n_estimators=196; total time=   3.6s
# [CV] END bootstrap=True, max_depth=37, min_samples_leaf=5, min_samples_split=17, n_estimators=196; total time=   3.5s
# [CV] END bootstrap=True, max_depth=37, min_samples_leaf=5, min_samples_split=17, n_estimators=196; total time=   3.6s
# [CV] END bootstrap=True, max_depth=37, min_samples_leaf=5, min_samples_split=17, n_estimators=196; total time=   3.6s
# [CV] END bootstrap=False, max_depth=39, min_samples_leaf=17, min_samples_split=18, n_estimators=221; total time=   3.6s
# [CV] END bootstrap=False, max_depth=39, min_samples_leaf=17, min_samples_split=18, n_estimators=221; total time=   3.8s
# [CV] END bootstrap=False, max_depth=39, min_samples_leaf=17, min_samples_split=18, n_estimators=221; total time=   3.9s
# [CV] END bootstrap=False, max_depth=34, min_samples_leaf=14, min_samples_split=7, n_estimators=148; total time=   2.7s
# [CV] END bootstrap=False, max_depth=34, min_samples_leaf=14, min_samples_split=7, n_estimators=148; total time=   2.8s
# [CV] END bootstrap=False, max_depth=34, min_samples_leaf=14, min_samples_split=7, n_estimators=148; total time=   2.9s
# [CV] END bootstrap=False, max_depth=34, min_samples_leaf=14, min_samples_split=7, n_estimators=148; total time=   2.9s
# [CV] END bootstrap=False, max_depth=39, min_samples_leaf=17, min_samples_split=18, n_estimators=221; total time=   4.1s
# [CV] END bootstrap=False, max_depth=39, min_samples_leaf=17, min_samples_split=18, n_estimators=221; total time=   3.9s
# [CV] END bootstrap=False, max_depth=34, min_samples_leaf=14, min_samples_split=7, n_estimators=148; total time=   2.9s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=5, min_samples_split=18, n_estimators=95; total time=   2.6s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=5, min_samples_split=18, n_estimators=95; total time=   2.6s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=5, min_samples_split=18, n_estimators=95; total time=   2.5s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=5, min_samples_split=18, n_estimators=95; total time=   2.4s
# [CV] END bootstrap=False, max_depth=45, min_samples_leaf=5, min_samples_split=18, n_estimators=95; total time=   2.6s
# [CV] END bootstrap=True, max_depth=35, min_samples_leaf=3, min_samples_split=2, n_estimators=165; total time=   3.7s
# [CV] END bootstrap=True, max_depth=35, min_samples_leaf=3, min_samples_split=2, n_estimators=165; total time=   3.7s
# [CV] END bootstrap=True, max_depth=35, min_samples_leaf=3, min_samples_split=2, n_estimators=165; total time=   3.8s
# [CV] END bootstrap=True, max_depth=35, min_samples_leaf=3, min_samples_split=2, n_estimators=165; total time=   3.7s
# [CV] END bootstrap=True, max_depth=35, min_samples_leaf=3, min_samples_split=2, n_estimators=165; total time=   3.6s
# [CV] END bootstrap=True, max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=177; total time=   4.2s
# [CV] END bootstrap=True, max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=177; total time=   4.3s
# [CV] END bootstrap=True, max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=177; total time=   4.3s
# [CV] END bootstrap=False, max_depth=29, min_samples_leaf=10, min_samples_split=4, n_estimators=153; total time=   3.1s
# [CV] END bootstrap=False, max_depth=29, min_samples_leaf=10, min_samples_split=4, n_estimators=153; total time=   3.2s
# [CV] END bootstrap=True, max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=177; total time=   4.2s
# [CV] END bootstrap=True, max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=177; total time=   4.2s
# [CV] END bootstrap=False, max_depth=29, min_samples_leaf=10, min_samples_split=4, n_estimators=153; total time=   3.2s
# [CV] END bootstrap=False, max_depth=28, min_samples_leaf=18, min_samples_split=16, n_estimators=135; total time=   2.3s
# [CV] END bootstrap=False, max_depth=29, min_samples_leaf=10, min_samples_split=4, n_estimators=153; total time=   3.1s
# [CV] END bootstrap=False, max_depth=28, min_samples_leaf=18, min_samples_split=16, n_estimators=135; total time=   2.3s
# [CV] END bootstrap=False, max_depth=29, min_samples_leaf=10, min_samples_split=4, n_estimators=153; total time=   3.1s
# [CV] END bootstrap=False, max_depth=28, min_samples_leaf=18, min_samples_split=16, n_estimators=135; total time=   2.3s
# [CV] END bootstrap=False, max_depth=28, min_samples_leaf=18, min_samples_split=16, n_estimators=135; total time=   2.3s
# [CV] END bootstrap=False, max_depth=28, min_samples_leaf=18, min_samples_split=16, n_estimators=135; total time=   2.3s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=10, min_samples_split=3, n_estimators=267; total time=   2.4s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=10, min_samples_split=3, n_estimators=267; total time=   2.3s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=10, min_samples_split=3, n_estimators=267; total time=   2.3s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=10, min_samples_split=3, n_estimators=267; total time=   2.4s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=10, min_samples_split=3, n_estimators=267; total time=   2.4s
# [CV] END bootstrap=True, max_depth=44, min_samples_leaf=1, min_samples_split=10, n_estimators=92; total time=   2.6s
# [CV] END bootstrap=True, max_depth=44, min_samples_leaf=1, min_samples_split=10, n_estimators=92; total time=   2.7s
# [CV] END bootstrap=True, max_depth=44, min_samples_leaf=1, min_samples_split=10, n_estimators=92; total time=   2.6s
# [CV] END bootstrap=True, max_depth=44, min_samples_leaf=1, min_samples_split=10, n_estimators=92; total time=   2.7s
# [CV] END bootstrap=True, max_depth=44, min_samples_leaf=1, min_samples_split=10, n_estimators=92; total time=   2.6s
# [CV] END bootstrap=False, max_depth=43, min_samples_leaf=10, min_samples_split=4, n_estimators=99; total time=   2.1s
# [CV] END bootstrap=False, max_depth=43, min_samples_leaf=10, min_samples_split=4, n_estimators=99; total time=   2.1s
# [CV] END bootstrap=False, max_depth=43, min_samples_leaf=10, min_samples_split=4, n_estimators=99; total time=   2.1s
# [CV] END bootstrap=False, max_depth=43, min_samples_leaf=10, min_samples_split=4, n_estimators=99; total time=   2.2s
# [CV] END bootstrap=True, max_depth=28, min_samples_leaf=13, min_samples_split=8, n_estimators=106; total time=   1.5s
# [CV] END bootstrap=False, max_depth=43, min_samples_leaf=10, min_samples_split=4, n_estimators=99; total time=   2.2s
# [CV] END bootstrap=True, max_depth=28, min_samples_leaf=13, min_samples_split=8, n_estimators=106; total time=   1.6s
# [CV] END bootstrap=True, max_depth=28, min_samples_leaf=13, min_samples_split=8, n_estimators=106; total time=   1.5s
# [CV] END bootstrap=True, max_depth=28, min_samples_leaf=13, min_samples_split=8, n_estimators=106; total time=   1.5s
# [CV] END bootstrap=True, max_depth=28, min_samples_leaf=13, min_samples_split=8, n_estimators=106; total time=   1.5s
# [CV] END bootstrap=False, max_depth=18, min_samples_leaf=12, min_samples_split=16, n_estimators=141; total time=   2.6s
# [CV] END bootstrap=False, max_depth=18, min_samples_leaf=12, min_samples_split=16, n_estimators=141; total time=   2.6s
# [CV] END bootstrap=False, max_depth=18, min_samples_leaf=12, min_samples_split=16, n_estimators=141; total time=   2.6s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=19, min_samples_split=18, n_estimators=229; total time=   2.3s
# [CV] END bootstrap=False, max_depth=18, min_samples_leaf=12, min_samples_split=16, n_estimators=141; total time=   2.5s
# [CV] END bootstrap=False, max_depth=18, min_samples_leaf=12, min_samples_split=16, n_estimators=141; total time=   2.7s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=19, min_samples_split=18, n_estimators=229; total time=   2.2s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=19, min_samples_split=18, n_estimators=229; total time=   2.1s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=19, min_samples_split=18, n_estimators=229; total time=   2.2s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=19, min_samples_split=18, n_estimators=229; total time=   2.3s
# [CV] END bootstrap=False, max_depth=49, min_samples_leaf=1, min_samples_split=9, n_estimators=287; total time=  11.8s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=15, min_samples_split=12, n_estimators=237; total time=   3.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=15, min_samples_split=12, n_estimators=237; total time=   3.1s
# [CV] END bootstrap=False, max_depth=49, min_samples_leaf=1, min_samples_split=9, n_estimators=287; total time=  11.8s
# [CV] END bootstrap=False, max_depth=49, min_samples_leaf=1, min_samples_split=9, n_estimators=287; total time=  12.0s
# [CV] END bootstrap=False, max_depth=49, min_samples_leaf=1, min_samples_split=9, n_estimators=287; total time=  12.0s
# [CV] END bootstrap=False, max_depth=49, min_samples_leaf=1, min_samples_split=9, n_estimators=287; total time=  12.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=15, min_samples_split=12, n_estimators=237; total time=   3.1s
# [CV] END bootstrap=True, max_depth=37, min_samples_leaf=8, min_samples_split=13, n_estimators=157; total time=   2.5s
# [CV] END bootstrap=True, max_depth=37, min_samples_leaf=8, min_samples_split=13, n_estimators=157; total time=   2.5s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=15, min_samples_split=12, n_estimators=237; total time=   3.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=15, min_samples_split=12, n_estimators=237; total time=   3.1s
# [CV] END bootstrap=True, max_depth=37, min_samples_leaf=8, min_samples_split=13, n_estimators=157; total time=   2.6s
# [CV] END bootstrap=True, max_depth=37, min_samples_leaf=8, min_samples_split=13, n_estimators=157; total time=   2.6s
# [CV] END bootstrap=True, max_depth=37, min_samples_leaf=8, min_samples_split=13, n_estimators=157; total time=   2.4s
# [CV] END bootstrap=True, max_depth=43, min_samples_leaf=4, min_samples_split=7, n_estimators=158; total time=   3.1s
# [CV] END bootstrap=False, max_depth=34, min_samples_leaf=15, min_samples_split=4, n_estimators=104; total time=   2.0s
# [CV] END bootstrap=False, max_depth=34, min_samples_leaf=15, min_samples_split=4, n_estimators=104; total time=   1.9s
# [CV] END bootstrap=False, max_depth=34, min_samples_leaf=15, min_samples_split=4, n_estimators=104; total time=   2.0s
# [CV] END bootstrap=True, max_depth=43, min_samples_leaf=4, min_samples_split=7, n_estimators=158; total time=   3.2s
# [CV] END bootstrap=True, max_depth=43, min_samples_leaf=4, min_samples_split=7, n_estimators=158; total time=   3.2s
# [CV] END bootstrap=True, max_depth=43, min_samples_leaf=4, min_samples_split=7, n_estimators=158; total time=   3.3s
# [CV] END bootstrap=True, max_depth=43, min_samples_leaf=4, min_samples_split=7, n_estimators=158; total time=   3.3s
# [CV] END bootstrap=False, max_depth=34, min_samples_leaf=15, min_samples_split=4, n_estimators=104; total time=   1.9s
# [CV] END bootstrap=False, max_depth=34, min_samples_leaf=15, min_samples_split=4, n_estimators=104; total time=   2.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=13, min_samples_split=19, n_estimators=173; total time=   3.1s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=13, min_samples_split=19, n_estimators=173; total time=   3.1s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=13, min_samples_split=19, n_estimators=173; total time=   3.1s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=13, min_samples_split=19, n_estimators=173; total time=   3.1s
# [CV] END bootstrap=False, max_depth=34, min_samples_leaf=19, min_samples_split=18, n_estimators=169; total time=   2.9s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=13, min_samples_split=19, n_estimators=173; total time=   3.3s
# [CV] END bootstrap=False, max_depth=34, min_samples_leaf=19, min_samples_split=18, n_estimators=169; total time=   2.9s
# [CV] END bootstrap=False, max_depth=34, min_samples_leaf=19, min_samples_split=18, n_estimators=169; total time=   3.0s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=1, min_samples_split=16, n_estimators=83; total time=   0.8s
# [CV] END bootstrap=False, max_depth=34, min_samples_leaf=19, min_samples_split=18, n_estimators=169; total time=   3.0s
# [CV] END bootstrap=False, max_depth=34, min_samples_leaf=19, min_samples_split=18, n_estimators=169; total time=   2.9s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=1, min_samples_split=16, n_estimators=83; total time=   0.8s
# [CV] END bootstrap=True, max_depth=23, min_samples_leaf=5, min_samples_split=10, n_estimators=189; total time=   3.3s
# [CV] END bootstrap=True, max_depth=23, min_samples_leaf=5, min_samples_split=10, n_estimators=189; total time=   3.3s
# [CV] END bootstrap=True, max_depth=23, min_samples_leaf=5, min_samples_split=10, n_estimators=189; total time=   3.3s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=1, min_samples_split=16, n_estimators=83; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=1, min_samples_split=16, n_estimators=83; total time=   0.8s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=1, min_samples_split=16, n_estimators=83; total time=   0.7s
# [CV] END bootstrap=True, max_depth=23, min_samples_leaf=5, min_samples_split=10, n_estimators=189; total time=   3.4s
# [CV] END bootstrap=True, max_depth=23, min_samples_leaf=5, min_samples_split=10, n_estimators=189; total time=   3.3s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=7, min_samples_split=6, n_estimators=71; total time=   1.2s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=7, min_samples_split=6, n_estimators=71; total time=   1.2s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=7, min_samples_split=6, n_estimators=71; total time=   1.3s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=7, min_samples_split=6, n_estimators=71; total time=   1.3s
# [CV] END bootstrap=True, max_depth=20, min_samples_leaf=7, min_samples_split=6, n_estimators=71; total time=   1.3s
# [CV] END bootstrap=False, max_depth=29, min_samples_leaf=8, min_samples_split=14, n_estimators=166; total time=   3.8s
# [CV] END bootstrap=False, max_depth=29, min_samples_leaf=8, min_samples_split=14, n_estimators=166; total time=   3.9s
# [CV] END bootstrap=False, max_depth=29, min_samples_leaf=8, min_samples_split=14, n_estimators=166; total time=   3.8s
# [CV] END bootstrap=False, max_depth=29, min_samples_leaf=8, min_samples_split=14, n_estimators=166; total time=   3.9s
# [CV] END bootstrap=False, max_depth=29, min_samples_leaf=8, min_samples_split=14, n_estimators=166; total time=   3.8s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=12, min_samples_split=17, n_estimators=228; total time=   2.2s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=12, min_samples_split=17, n_estimators=228; total time=   2.5s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=12, min_samples_split=17, n_estimators=228; total time=   2.5s
# [CV] END bootstrap=True, max_depth=26, min_samples_leaf=14, min_samples_split=6, n_estimators=96; total time=   1.6s
# [CV] END bootstrap=True, max_depth=26, min_samples_leaf=14, min_samples_split=6, n_estimators=96; total time=   1.6s
# [CV] END bootstrap=True, max_depth=26, min_samples_leaf=14, min_samples_split=6, n_estimators=96; total time=   1.7s
# [CV] END bootstrap=True, max_depth=26, min_samples_leaf=14, min_samples_split=6, n_estimators=96; total time=   1.5s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=12, min_samples_split=17, n_estimators=228; total time=   2.4s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=12, min_samples_split=17, n_estimators=228; total time=   2.4s
# [CV] END bootstrap=True, max_depth=26, min_samples_leaf=14, min_samples_split=6, n_estimators=96; total time=   1.4s
# [CV] END bootstrap=True, max_depth=34, min_samples_leaf=14, min_samples_split=6, n_estimators=253; total time=   4.4s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=16, min_samples_split=8, n_estimators=149; total time=   3.8s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=16, min_samples_split=8, n_estimators=149; total time=   3.9s
# [CV] END bootstrap=True, max_depth=34, min_samples_leaf=14, min_samples_split=6, n_estimators=253; total time=   4.7s
# [CV] END bootstrap=True, max_depth=34, min_samples_leaf=14, min_samples_split=6, n_estimators=253; total time=   4.5s
# [CV] END bootstrap=True, max_depth=34, min_samples_leaf=14, min_samples_split=6, n_estimators=253; total time=   4.7s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=16, min_samples_split=8, n_estimators=149; total time=   3.8s
# [CV] END bootstrap=True, max_depth=34, min_samples_leaf=14, min_samples_split=6, n_estimators=253; total time=   4.7s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=16, min_samples_split=8, n_estimators=149; total time=   4.2s
# [CV] END bootstrap=False, max_depth=30, min_samples_leaf=16, min_samples_split=8, n_estimators=149; total time=   4.2s
# [CV] END bootstrap=True, max_depth=34, min_samples_leaf=5, min_samples_split=11, n_estimators=295; total time=   8.4s
# [CV] END bootstrap=True, max_depth=34, min_samples_leaf=5, min_samples_split=11, n_estimators=295; total time=   8.4s
# [CV] END bootstrap=True, max_depth=34, min_samples_leaf=5, min_samples_split=11, n_estimators=295; total time=   8.6s
# [CV] END bootstrap=True, max_depth=34, min_samples_leaf=5, min_samples_split=11, n_estimators=295; total time=   8.6s
# [CV] END bootstrap=True, max_depth=34, min_samples_leaf=5, min_samples_split=11, n_estimators=295; total time=   8.6s
# [CV] END bootstrap=True, max_depth=40, min_samples_leaf=2, min_samples_split=11, n_estimators=299; total time=  11.2s
# [CV] END bootstrap=True, max_depth=40, min_samples_leaf=2, min_samples_split=11, n_estimators=299; total time=  10.7s
# [CV] END bootstrap=True, max_depth=40, min_samples_leaf=2, min_samples_split=11, n_estimators=299; total time=  10.8s
# [CV] END bootstrap=True, max_depth=40, min_samples_leaf=2, min_samples_split=11, n_estimators=299; total time=  10.1s
# [CV] END bootstrap=True, max_depth=40, min_samples_leaf=2, min_samples_split=11, n_estimators=299; total time=  10.2s
# [CV] END bootstrap=True, max_depth=36, min_samples_leaf=1, min_samples_split=6, n_estimators=286; total time=  11.2s
# [CV] END bootstrap=True, max_depth=36, min_samples_leaf=1, min_samples_split=6, n_estimators=286; total time=  11.2s
# [CV] END bootstrap=True, max_depth=36, min_samples_leaf=1, min_samples_split=6, n_estimators=286; total time=  11.3s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=16, min_samples_split=3, n_estimators=290; total time=   6.6s
# [CV] END bootstrap=True, max_depth=36, min_samples_leaf=1, min_samples_split=6, n_estimators=286; total time=  11.5s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=16, min_samples_split=3, n_estimators=290; total time=   7.0s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=16, min_samples_split=3, n_estimators=290; total time=   7.4s
# [CV] END bootstrap=True, max_depth=36, min_samples_leaf=1, min_samples_split=6, n_estimators=286; total time=  11.7s
# [CV] END bootstrap=False, max_depth=36, min_samples_leaf=12, min_samples_split=19, n_estimators=212; total time=   6.4s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=16, min_samples_split=3, n_estimators=290; total time=   7.7s
# [CV] END bootstrap=False, max_depth=36, min_samples_leaf=12, min_samples_split=19, n_estimators=212; total time=   6.2s
# [CV] END bootstrap=False, max_depth=20, min_samples_leaf=16, min_samples_split=3, n_estimators=290; total time=   7.9s
# [CV] END bootstrap=False, max_depth=36, min_samples_leaf=12, min_samples_split=19, n_estimators=212; total time=   6.3s
# [CV] END bootstrap=False, max_depth=36, min_samples_leaf=12, min_samples_split=19, n_estimators=212; total time=   6.3s
# [CV] END bootstrap=False, max_depth=36, min_samples_leaf=12, min_samples_split=19, n_estimators=212; total time=   6.6s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=217; total time=   3.7s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=217; total time=   3.1s
# [CV] END bootstrap=False, max_depth=37, min_samples_leaf=1, min_samples_split=12, n_estimators=150; total time=   8.2s
# [CV] END bootstrap=False, max_depth=37, min_samples_leaf=1, min_samples_split=12, n_estimators=150; total time=   8.1s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=217; total time=   2.8s
# [CV] END bootstrap=False, max_depth=37, min_samples_leaf=1, min_samples_split=12, n_estimators=150; total time=   8.1s
# [CV] END bootstrap=False, max_depth=37, min_samples_leaf=1, min_samples_split=12, n_estimators=150; total time=   7.8s
# [CV] END bootstrap=False, max_depth=37, min_samples_leaf=1, min_samples_split=12, n_estimators=150; total time=   7.9s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=217; total time=   2.6s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=217; total time=   2.1s
# Best Parameters:
#  {'bootstrap': False, 'max_depth': 49, 'min_samples_leaf': 1, 'min_samples_split': 9, 'n_estimators': 287}
# Best Score:
#  0.7762349799732977

# %%
from sklearn.model_selection import cross_val_score

# Initialize the classifier with the best parameters from RandomizedSearchCV
best_rf = random_search.best_estimator_

# Perform cross-validation
cv_scores = cross_val_score(best_rf, X_res, y_res, cv=5, scoring='accuracy')

# Print the cross-validation results
print("Cross-Validation Scores:\n", cv_scores)
print("Mean CV Score:\n", cv_scores.mean())
# Out:
# Cross-Validation Scores:
#  [0.68878505 0.68831776 0.68411215 0.6682243  0.68878505]
# Mean CV Score:
#  0.6836448598130842

# %%
# Make predictions on the test set
y_test_pred = best_rf.predict(X_test)

# Print classification report
print('Classification Report:\n', classification_report(y_test, y_test_pred, target_names=LABELS))

# Print confusion matrix
print('Confusion Matrix:\n', confusion_matrix(y_test, y_test_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#         Show       0.84      0.75      0.79      1630
#      No Show       0.77      0.86      0.81      1580
#
#     accuracy                           0.80      3210
#    macro avg       0.81      0.80      0.80      3210
# weighted avg       0.81      0.80      0.80      3210
#
# Confusion Matrix:
#  [[1220  410]
#  [ 227 1353]]

# %%
# Make predictions on the test set
y_test_pred = best_rf.predict(X_test)

# Print classification report
print('Classification Report:\n', classification_report(y_test, y_test_pred, target_names=LABELS))

# Print confusion matrix
print('Confusion Matrix:\n', confusion_matrix(y_test, y_test_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#         Show       0.84      0.75      0.79      1630
#      No Show       0.77      0.86      0.81      1580
#
#     accuracy                           0.80      3210
#    macro avg       0.81      0.80      0.80      3210
# weighted avg       0.81      0.80      0.80      3210
#
# Confusion Matrix:
#  [[1220  410]
#  [ 227 1353]]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example: Suppose we have the cross-validation scores for three different models
models = ['Random Forest', 'SVM', 'Logistic Regression']
cv_scores = {
    'Random Forest': [0.688, 0.688, 0.684, 0.668, 0.688],
    'SVM': [0.670, 0.672, 0.668, 0.664, 0.670],
    'Logistic Regression': [0.662, 0.660, 0.658, 0.660, 0.662]
}

# Calculate the mean cross-validation score for each model
mean_scores = {model: np.mean(scores) for model, scores in cv_scores.items()}

# Plot the cross-validation scores for each model
plt.figure(figsize=(10, 6))
plt.barh(list(mean_scores.keys()), list(mean_scores.values()), color='skyblue')
plt.xlabel('Mean Cross-Validation Accuracy')
plt.ylabel('Model')
plt.title('Model Performance Comparison')
plt.xlim(0, 1)  # Assuming accuracy scores range from 0 to 1

# Display the mean scores on the bars
for index, value in enumerate(mean_scores.values()):
    plt.text(value, index, f'{value:.3f}')

plt.show()
